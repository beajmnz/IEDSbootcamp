# %% [markdown]
# # Modifying DataFrames

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Creation

# %% [markdown]
# Creation of an example DataFrame (starting from a dictionary of dictionaries):

# %%
data = {
    "Capital": {
        "Spain": "Madrid",
        "Belgium": "Brussels",
        "France": "Paris",
        "Italy": "Roma",
        "Germany": "Berlin",
        "Portugal": "Lisbon",
        "Norway": "Oslo",
        "Greece": "Athens",
    },
    "Population": {
        "Spain": 46733038,
        "Belgium": 11449656,
        "France": 67076000,
        "Italy": 60390560,
        "Germany": 83122889,
        "Portugal": 10295909,
        "Norway": 5391369,
        "Greece": 10718565,
    },
    "Monarch": {
        "Spain": "Felipe VI",
        "Belgium": "Philippe",
        "Norway": "Harald V",
    },
    "Area": {
        "Spain": 505990,
        "Belgium": 30688,
        "France": 640679,
        "Italy": 301340,
        "Germany": 357022,
        "Portugal": 92212,
        "Norway": 385207,
        "Greece": 131957,
    },
}

# %%
# For now, let's forget about these steps:
df = pd.DataFrame(data)
df["Capital"] = df["Capital"].astype("string")
df["Monarch"] = df["Monarch"].astype("string")

# %% [markdown]
# Apple stock data, taken from the [`matplotlib` sample datasets](https://github.com/matplotlib/sample_data/blob/master/aapl.csv)

# %%
# For now, let's forget about these steps:
apple = pd.read_csv("AAPL.csv")
apple["Date"] = apple["Date"].astype("datetime64[ns]")
apple = apple.set_index("Date")
apple = apple.sort_index()

# %% [markdown]
# ## Demo 1: Create or modify a column

# %%
df
# Out:
#            Capital  Population    Monarch    Area
# Spain       Madrid    46733038  Felipe VI  505990
# Belgium   Brussels    11449656   Philippe   30688
# France       Paris    67076000       <NA>  640679
# Italy         Roma    60390560       <NA>  301340
# Germany     Berlin    83122889       <NA>  357022
# Portugal    Lisbon    10295909       <NA>   92212
# Norway        Oslo     5391369   Harald V  385207
# Greece      Athens    10718565       <NA>  131957

# %% [markdown]
# Add a new column:

# %%
df["Population"]
# Out:
# Spain       46733038
# Belgium     11449656
# France      67076000
# Italy       60390560
# Germany     83122889
# Portugal    10295909
# Norway       5391369
# Greece      10718565
# Name: Population, dtype: int64

# %%
df["Area"]
# Out:
# Spain       505990
# Belgium      30688
# France      640679
# Italy       301340
# Germany     357022
# Portugal     92212
# Norway      385207
# Greece      131957
# Name: Area, dtype: int64

# %%
df["Population"] / df["Area"]
# Out:
# Spain        92.359608
# Belgium     373.098801
# France      104.695175
# Italy       200.406717
# Germany     232.822876
# Portugal    111.654763
# Norway       13.996031
# Greece       81.227711
# dtype: float64

# %%
df["Density"] = df["Population"] / df["Area"]

# %%
df
# Out:
#            Capital  Population    Monarch    Area     Density
# Spain       Madrid    46733038  Felipe VI  505990   92.359608
# Belgium   Brussels    11449656   Philippe   30688  373.098801
# France       Paris    67076000       <NA>  640679  104.695175
# Italy         Roma    60390560       <NA>  301340  200.406717
# Germany     Berlin    83122889       <NA>  357022  232.822876
# Portugal    Lisbon    10295909       <NA>   92212  111.654763
# Norway        Oslo     5391369   Harald V  385207   13.996031
# Greece      Athens    10718565       <NA>  131957   81.227711

# %% [markdown]
# Modify a column:

# %%
df["Population"]
# Out:
# Spain       46.733038
# Belgium     11.449656
# France      67.076000
# Italy       60.390560
# Germany     83.122889
# Portugal    10.295909
# Norway       5.391369
# Greece      10.718565
# Name: Population, dtype: float64

# %%
df["Population"] / 1_000_000
# Out:
# Spain       0.000047
# Belgium     0.000011
# France      0.000067
# Italy       0.000060
# Germany     0.000083
# Portugal    0.000010
# Norway      0.000005
# Greece      0.000011
# Name: Population, dtype: float64

# %%
df["Population"] = df["Population"] / 1_000_000

# %%
df
# Out:
#            Capital  Population    Monarch    Area     Density
# Spain       Madrid   46.733038  Felipe VI  505990   92.359608
# Belgium   Brussels   11.449656   Philippe   30688  373.098801
# France       Paris   67.076000       <NA>  640679  104.695175
# Italy         Roma   60.390560       <NA>  301340  200.406717
# Germany     Berlin   83.122889       <NA>  357022  232.822876
# Portugal    Lisbon   10.295909       <NA>   92212  111.654763
# Norway        Oslo    5.391369   Harald V  385207   13.996031
# Greece      Athens   10.718565       <NA>  131957   81.227711

# %% [markdown]
# ## Exercise 1

# %%
apple.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 1984-09-07  26.50  26.87  26.25  26.50  2981600       3.02
# 1984-09-10  26.50  26.62  25.87  26.37  2346400       3.01
# 1984-09-11  26.62  27.37  26.62  26.87  5444000       3.07
# 1984-09-12  26.87  27.00  26.12  26.12  4773600       2.98
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14

# %% [markdown]
# Create a new "Spread" column, with the difference between "High" and "Low":

# %%
apple["Spread"] = apple["High"] - apple["Low"]

# %%
apple
# Out:
#               Open    High     Low   Close    Volume  Adj Close  Spread
# Date
# 1984-09-07   26.50   26.87   26.25   26.50   2981600       3.02    0.62
# 1984-09-10   26.50   26.62   25.87   26.37   2346400       3.01    0.75
# 1984-09-11   26.62   27.37   26.62   26.87   5444000       3.07    0.75
# 1984-09-12   26.87   27.00   26.12   26.12   4773600       2.98    0.88
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14    0.12
# ...            ...     ...     ...     ...       ...        ...     ...
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79   10.65
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74    9.20
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80   15.00
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26    9.51
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08   13.26
#
# [6081 rows x 7 columns]

# %% [markdown]
# ## Demo 2: Reorder columns

# %%
df
# Out:
#            Capital  Population    Monarch    Area     Density
# Spain       Madrid   46.733038  Felipe VI  505990   92.359608
# Belgium   Brussels   11.449656   Philippe   30688  373.098801
# France       Paris   67.076000       <NA>  640679  104.695175
# Italy         Roma   60.390560       <NA>  301340  200.406717
# Germany     Berlin   83.122889       <NA>  357022  232.822876
# Portugal    Lisbon   10.295909       <NA>   92212  111.654763
# Norway        Oslo    5.391369   Harald V  385207   13.996031
# Greece      Athens   10.718565       <NA>  131957   81.227711

# %% [markdown]
# Reorder columns:

# %%
df.columns
# Out:
# Index(['Capital', 'Population', 'Monarch', 'Area', 'Density'], dtype='object')

# %%
columns = ["Population", "Area", "Density", "Capital", "Monarch"]

# %%
df = df.reindex(columns=columns)

# %%
df
# Out:
#           Population    Area     Density   Capital    Monarch
# Spain      46.733038  505990   92.359608    Madrid  Felipe VI
# Belgium    11.449656   30688  373.098801  Brussels   Philippe
# France     67.076000  640679  104.695175     Paris       <NA>
# Italy      60.390560  301340  200.406717      Roma       <NA>
# Germany    83.122889  357022  232.822876    Berlin       <NA>
# Portugal   10.295909   92212  111.654763    Lisbon       <NA>
# Norway      5.391369  385207   13.996031      Oslo   Harald V
# Greece     10.718565  131957   81.227711    Athens       <NA>

# %%
df.columns
# Out:
# Index(['Population', 'Area', 'Density', 'Capital', 'Monarch'], dtype='object')

# %% [markdown]
# ## Exercise 2

# %%
apple.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close  Spread
# Date
# 1984-09-07  26.50  26.87  26.25  26.50  2981600       3.02    0.62
# 1984-09-10  26.50  26.62  25.87  26.37  2346400       3.01    0.75
# 1984-09-11  26.62  27.37  26.62  26.87  5444000       3.07    0.75
# 1984-09-12  26.87  27.00  26.12  26.12  4773600       2.98    0.88
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14    0.12

# %% [markdown]
# Reorder columns to have "Open" and "Close", then "High", "Low", and "Spread", followed by "Volume" ("Adj Close"  gets removed):

# %%
apple.reindex(columns=["Open","Close","High","Low","Spread","Volume"])
# Out:
#               Open   Close    High     Low  Spread    Volume
# Date
# 1984-09-07   26.50   26.50   26.87   26.25    0.62   2981600
# 1984-09-10   26.50   26.37   26.62   25.87    0.75   2346400
# 1984-09-11   26.62   26.87   27.37   26.62    0.75   5444000
# 1984-09-12   26.87   26.12   27.00   26.12    0.88   4773600
# 1984-09-13   27.50   27.50   27.62   27.50    0.12   7429600
# ...            ...     ...     ...     ...     ...       ...
# 2008-10-08   85.91   89.79   96.33   85.68   10.65  78847900
# 2008-10-09   93.35   88.74   95.80   86.60    9.20  57763700
# 2008-10-10   85.70   96.80  100.00   85.00   15.00  79260700
# 2008-10-13  104.55  110.26  110.53  101.02    9.51  54967000
# 2008-10-14  116.26  104.08  116.40  103.14   13.26  70749800
#
# [6081 rows x 6 columns]

# %%
apple = apple.reindex(columns=["Open","Close","High","Low","Spread","Volume"])

# %% [markdown]
# ## Demo 3: Rename columns

# %%
df
# Out:
#           Population    Area     Density   Capital    Monarch
# Spain      46.733038  505990   92.359608    Madrid  Felipe VI
# Belgium    11.449656   30688  373.098801  Brussels   Philippe
# France     67.076000  640679  104.695175     Paris       <NA>
# Italy      60.390560  301340  200.406717      Roma       <NA>
# Germany    83.122889  357022  232.822876    Berlin       <NA>
# Portugal   10.295909   92212  111.654763    Lisbon       <NA>
# Norway      5.391369  385207   13.996031      Oslo   Harald V
# Greece     10.718565  131957   81.227711    Athens       <NA>

# %% [markdown]
# Rename columns:

# %%
df.columns
# Out:
# Index(['Population', 'Area', 'Density', 'Capital', 'Monarch'], dtype='object')

# %%
columns = {
    "Population": "Population [M]",
    "Area": "Area [km*km]",
    "Monarch": "King/Queen",
}

# %%
df = df.rename(columns=columns)

# %%
df
# Out:
#           Population [M]  Area [km*km]     Density   Capital King/Queen
# Spain          46.733038        505990   92.359608    Madrid  Felipe VI
# Belgium        11.449656         30688  373.098801  Brussels   Philippe
# France         67.076000        640679  104.695175     Paris       <NA>
# Italy          60.390560        301340  200.406717      Roma       <NA>
# Germany        83.122889        357022  232.822876    Berlin       <NA>
# Portugal       10.295909         92212  111.654763    Lisbon       <NA>
# Norway          5.391369        385207   13.996031      Oslo   Harald V
# Greece         10.718565        131957   81.227711    Athens       <NA>

# %%
df.columns
# Out:
# Index(['Population [M]', 'Area [km*km]', 'Density', 'Capital', 'King/Queen'], dtype='object')

# %% [markdown]
# ## Exercise 3

# %%
apple.head()
# Out:
#              Open  Close   High    Low  Spread   Volume
# Date
# 1984-09-07  26.50  26.50  26.87  26.25    0.62  2981600
# 1984-09-10  26.50  26.37  26.62  25.87    0.75  2346400
# 1984-09-11  26.62  26.87  27.37  26.62    0.75  5444000
# 1984-09-12  26.87  26.12  27.00  26.12    0.88  4773600
# 1984-09-13  27.50  27.50  27.62  27.50    0.12  7429600

# %% [markdown]
# Rename the "Spread" column to "Difference", and the "Open" to "Open Value":

# %%
new_cols = {
    "Spread":"Difference",
    "Open":"Open Value"
}

# %%
apple = apple.rename(columns=new_cols)

# %%
apple
# Out:
#             Open Value   Close    High     Low  Difference    Volume
# Date
# 1984-09-07       26.50   26.50   26.87   26.25        0.62   2981600
# 1984-09-10       26.50   26.37   26.62   25.87        0.75   2346400
# 1984-09-11       26.62   26.87   27.37   26.62        0.75   5444000
# 1984-09-12       26.87   26.12   27.00   26.12        0.88   4773600
# 1984-09-13       27.50   27.50   27.62   27.50        0.12   7429600
# ...                ...     ...     ...     ...         ...       ...
# 2008-10-08       85.91   89.79   96.33   85.68       10.65  78847900
# 2008-10-09       93.35   88.74   95.80   86.60        9.20  57763700
# 2008-10-10       85.70   96.80  100.00   85.00       15.00  79260700
# 2008-10-13      104.55  110.26  110.53  101.02        9.51  54967000
# 2008-10-14      116.26  104.08  116.40  103.14       13.26  70749800
#
# [6081 rows x 6 columns]
