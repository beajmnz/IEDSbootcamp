# %% [markdown]
# # Missing values

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Creation

# %% [markdown]
# Creation of an example DataFrame (starting from a dictionary of dictionaries):

# %%
data = {
    "Capital": {
        "Spain": "Madrid",
        "Belgium": "Brussels",
        "France": "Paris",
        "Italy": "Roma",
        "Germany": "Berlin",
        "Portugal": "Lisbon",
        "Norway": "Oslo",
        "Greece": "Athens",
    },
    "Population": {
        "Spain": 46733038,
        "Belgium": 11449656,
        "France": 67076000,
        "Italy": 60390560,
        "Germany": 83122889,
        "Portugal": 10295909,
        "Norway": 5391369,
        "Greece": 10718565,
    },
    "Monarch": {
        "Spain": "Felipe VI",
        "Belgium": "Philippe",
        "Norway": "Harald V",
    },
    "Area": {
        "Spain": 505990,
        "Belgium": 30688,
        "France": 640679,
        "Italy": 301340,
        "Germany": None,
        "Portugal": 92212,
        "Norway": 385207,
        "Greece": 131957,
    },
    "Currency": {
        "Spain": "EUR",
        "Belgium": "EUR",
        "France": "EUR",
        "Italy": "EUR",
        "Germany": "EUR",
        "Portugal": None,
        "Norway": "NOK",
        "Greece": "EUR",
    },
    "Formation": {
        "Spain": "1715-06-09",
        "Belgium": "1830-10-04",
        "France": "1792-09-22",
        "Italy": None,
        "Germany": None,
        "Portugal": None,
        "Norway": None,
        "Greece": None,
    },
}

# %%
# For now, let's forget about these steps:
df = pd.DataFrame(data)
df["Density"] = df["Population"] / df["Area"]
df["Capital"] = df["Capital"].astype("string")
df["Monarch"] = df["Monarch"].astype("string")
df["Area"] = df["Area"].astype("Int64")
df["Currency"] = df["Currency"].astype("category")
df["Formation"] = df["Formation"].astype("datetime64[ns]")

# %% [markdown]
# Apple stock data, taken from the [`matplotlib` sample datasets](https://github.com/matplotlib/sample_data/blob/master/aapl.csv)

# %%
# For now, let's forget about these steps:
apple = pd.read_csv("AAPL.csv")
apple["Date"] = apple["Date"].astype("datetime64[ns]")
apple = apple.set_index("Date")
apple = apple.sort_index()
apple.at["1984-09-07", "Open"] = None
apple.loc["1984-09-10":"1984-09-11", "High"] = None
apple.loc["1984-09-10":"1984-09-12", "Low"] = None

# %% [markdown]
# ## DataFrames

# %%
df
# Out:
#            Capital  Population    Monarch    Area Currency  Formation  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium   Brussels    11449656   Philippe   30688      EUR 1830-10-04
# France       Paris    67076000       <NA>  640679      EUR 1792-09-22
# Italy         Roma    60390560       <NA>  301340      EUR        NaT
# Germany     Berlin    83122889       <NA>    <NA>      EUR        NaT
# Portugal    Lisbon    10295909       <NA>   92212      NaN        NaT
# Norway        Oslo     5391369   Harald V  385207      NOK        NaT
# Greece      Athens    10718565       <NA>  131957      EUR        NaT
#
#              Density
# Spain      92.359608
# Belgium   373.098801
# France    104.695175
# Italy     200.406717
# Germany          NaN
# Portugal  111.654763
# Norway     13.996031
# Greece     81.227711

# %%
df.dtypes
# Out:
# Capital               string
# Population             int64
# Monarch               string
# Area                   Int64
# Currency            category
# Formation     datetime64[ns]
# Density              float64
# dtype: object

# %%
apple.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 1984-09-07    NaN  26.87  26.25  26.50  2981600       3.02
# 1984-09-10  26.50    NaN    NaN  26.37  2346400       3.01
# 1984-09-11  26.62    NaN    NaN  26.87  5444000       3.07
# 1984-09-12  26.87  27.00    NaN  26.12  4773600       2.98
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14

# %%
apple.count()
# Out:
# Open         6080
# High         6079
# Low          6078
# Close        6081
# Volume       6081
# Adj Close    6081
# dtype: int64

# %% [markdown]
# ## Demo 1: Drop rows with missing values

# %%
df
# Out:
#            Capital  Population    Monarch    Area Currency  Formation  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium   Brussels    11449656   Philippe   30688      EUR 1830-10-04
# France       Paris    67076000       <NA>  640679      EUR 1792-09-22
# Italy         Roma    60390560       <NA>  301340      EUR        NaT
# Germany     Berlin    83122889       <NA>    <NA>      EUR        NaT
# Portugal    Lisbon    10295909       <NA>   92212      NaN        NaT
# Norway        Oslo     5391369   Harald V  385207      NOK        NaT
# Greece      Athens    10718565       <NA>  131957      EUR        NaT
#
#              Density
# Spain      92.359608
# Belgium   373.098801
# France    104.695175
# Italy     200.406717
# Germany          NaN
# Portugal  111.654763
# Norway     13.996031
# Greece     81.227711

# %% [markdown]
# Count non-missing values:

# %%
df.count()
# Out:
# Capital       8
# Population    8
# Monarch       3
# Area          7
# Currency      7
# Formation     3
# Density       7
# dtype: int64

# %% [markdown]
# Drop rows with missing values:

# %%
df.dropna()
# Out:
#           Capital  Population    Monarch    Area Currency  Formation  \
# Spain      Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium  Brussels    11449656   Philippe   30688      EUR 1830-10-04
#
#             Density
# Spain     92.359608
# Belgium  373.098801

# %% [markdown]
# Drop rows with missing values in specific columns:

# %%
df.dropna(subset=["Area", "Population"])
# Out:
#            Capital  Population    Monarch    Area Currency  Formation  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium   Brussels    11449656   Philippe   30688      EUR 1830-10-04
# France       Paris    67076000       <NA>  640679      EUR 1792-09-22
# Italy         Roma    60390560       <NA>  301340      EUR        NaT
# Portugal    Lisbon    10295909       <NA>   92212      NaN        NaT
# Norway        Oslo     5391369   Harald V  385207      NOK        NaT
# Greece      Athens    10718565       <NA>  131957      EUR        NaT
#
#              Density
# Spain      92.359608
# Belgium   373.098801
# France    104.695175
# Italy     200.406717
# Portugal  111.654763
# Norway     13.996031
# Greece     81.227711

# %% [markdown]
# ## Exercise 1

# %%
apple.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 1984-09-07    NaN  26.87  26.25  26.50  2981600       3.02
# 1984-09-10  26.50    NaN    NaN  26.37  2346400       3.01
# 1984-09-11  26.62    NaN    NaN  26.87  5444000       3.07
# 1984-09-12  26.87  27.00    NaN  26.12  4773600       2.98
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14

# %% [markdown]
# Count non-missing values:

# %%
apple.count()
# Out:
# Open         6080
# High         6079
# Low          6078
# Close        6081
# Volume       6081
# Adj Close    6081
# dtype: int64

# %% [markdown]
# Drop rows with missing values:

# %%
apple.dropna()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# 1984-09-14   27.62   28.50   27.62   27.87   8826400       3.18
# 1984-09-17   28.62   29.00   28.62   28.62   6886400       3.27
# 1984-09-18   28.62   28.87   27.62   27.62   3495200       3.15
# 1984-09-19   27.62   27.87   27.00   27.00   3816000       3.08
# ...            ...     ...     ...     ...       ...        ...
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
#
# [6077 rows x 6 columns]

# %% [markdown]
# Drop rows with missing values in the "Open" and "High" columns:

# %%
apple.dropna(subset=["Open","High"])
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-12   26.87   27.00     NaN   26.12   4773600       2.98
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# 1984-09-14   27.62   28.50   27.62   27.87   8826400       3.18
# 1984-09-17   28.62   29.00   28.62   28.62   6886400       3.27
# 1984-09-18   28.62   28.87   27.62   27.62   3495200       3.15
# ...            ...     ...     ...     ...       ...        ...
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
#
# [6078 rows x 6 columns]

# %% [markdown]
# Drop rows with missing values in the "Open" column:

# %%
apple.dropna(subset=["Open"])
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-10   26.50     NaN     NaN   26.37   2346400       3.01
# 1984-09-11   26.62     NaN     NaN   26.87   5444000       3.07
# 1984-09-12   26.87   27.00     NaN   26.12   4773600       2.98
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# 1984-09-14   27.62   28.50   27.62   27.87   8826400       3.18
# ...            ...     ...     ...     ...       ...        ...
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
#
# [6080 rows x 6 columns]

# %% [markdown]
# ## Demo 2: Replace missing values by a constant

# %%
df
# Out:
#            Capital  Population    Monarch    Area Currency  Formation  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium   Brussels    11449656   Philippe   30688      EUR 1830-10-04
# France       Paris    67076000       <NA>  640679      EUR 1792-09-22
# Italy         Roma    60390560       <NA>  301340      EUR        NaT
# Germany     Berlin    83122889       <NA>    <NA>      EUR        NaT
# Portugal    Lisbon    10295909       <NA>   92212      NaN        NaT
# Norway        Oslo     5391369   Harald V  385207      NOK        NaT
# Greece      Athens    10718565       <NA>  131957      EUR        NaT
#
#              Density
# Spain      92.359608
# Belgium   373.098801
# France    104.695175
# Italy     200.406717
# Germany          NaN
# Portugal  111.654763
# Norway     13.996031
# Greece     81.227711

# %% [markdown]
# Replace missing values in a column by a constant:

# %%
df["Monarch"].fillna("")
# Out:
# Spain       Felipe VI
# Belgium      Philippe
# France
# Italy
# Germany
# Portugal
# Norway       Harald V
# Greece
# Name: Monarch, dtype: string

# %%
df["Monarch"] = df["Monarch"].fillna("")

# %%
df
# Out:
#            Capital  Population    Monarch    Area Currency  Formation  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR 1715-06-09
# Belgium   Brussels    11449656   Philippe   30688      EUR 1830-10-04
# France       Paris    67076000             640679      EUR 1792-09-22
# Italy         Roma    60390560             301340      EUR        NaT
# Germany     Berlin    83122889               <NA>      EUR        NaT
# Portugal    Lisbon    10295909              92212      NaN        NaT
# Norway        Oslo     5391369   Harald V  385207      NOK        NaT
# Greece      Athens    10718565             131957      EUR        NaT
#
#              Density
# Spain      92.359608
# Belgium   373.098801
# France    104.695175
# Italy     200.406717
# Germany          NaN
# Portugal  111.654763
# Norway     13.996031
# Greece     81.227711

# %% [markdown]
# Replace missing values in several columns by constants:

# %%
value = {
    "Area": 0,
    "Formation": "---",
}

# %%
df.fillna(value=value)
# Out:
#            Capital  Population    Monarch    Area Currency  \
# Spain       Madrid    46733038  Felipe VI  505990      EUR
# Belgium   Brussels    11449656   Philippe   30688      EUR
# France       Paris    67076000             640679      EUR
# Italy         Roma    60390560             301340      EUR
# Germany     Berlin    83122889                  0      EUR
# Portugal    Lisbon    10295909              92212      NaN
# Norway        Oslo     5391369   Harald V  385207      NOK
# Greece      Athens    10718565             131957      EUR
#
#                     Formation     Density
# Spain     1715-06-09 00:00:00   92.359608
# Belgium   1830-10-04 00:00:00  373.098801
# France    1792-09-22 00:00:00  104.695175
# Italy                     ---  200.406717
# Germany                   ---         NaN
# Portugal                  ---  111.654763
# Norway                    ---   13.996031
# Greece                    ---   81.227711

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note:</b> The fill value must be consistent with the data type of the column.
#
# </div>

# %% [markdown]
# ## Exercise 2

# %%
apple.head()
# Out:
#              Open   High    Low  Close   Volume  Adj Close
# Date
# 1984-09-07    NaN  26.87  26.25  26.50  2981600       3.02
# 1984-09-10  26.50    NaN    NaN  26.37  2346400       3.01
# 1984-09-11  26.62    NaN    NaN  26.87  5444000       3.07
# 1984-09-12  26.87  27.00    NaN  26.12  4773600       2.98
# 1984-09-13  27.50  27.62  27.50  27.50  7429600       3.14

# %% [markdown]
# Replace missing values in the "Low" column by zero:

# %%
apple['Low'] = apple['Low'].fillna(0)

# %%
apple
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-07     NaN   26.87   26.25   26.50   2981600       3.02
# 1984-09-10   26.50     NaN    0.00   26.37   2346400       3.01
# 1984-09-11   26.62     NaN    0.00   26.87   5444000       3.07
# 1984-09-12   26.87   27.00    0.00   26.12   4773600       2.98
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# ...            ...     ...     ...     ...       ...        ...
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
#
# [6081 rows x 6 columns]
