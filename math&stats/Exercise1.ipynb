# %% [markdown]
# # Exercise 1
# ##

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

data = pd.read_csv('Data Sets/hsb2.txt',sep='\t')

# %%
data.head()
# Out:
#     id  gender   race     ses  schtyp        prog  read  write  math  science  \
# 0   70    male  white     low  public     general    57     52    41       47
# 1  121  female  white  middle  public  vocational    68     59    53       63
# 2   86    male  white    high  public     general    44     33    54       58
# 3  141    male  white    high  public  vocational    63     44    47       53
# 4  172    male  white  middle  public    academic    47     52    57       53
#
#    socst
# 0     57
# 1     61
# 2     31
# 3     56
# 4     61

# %% [markdown]
# ## Exercises
#
# 1.-**Explain the frequency distribution of the 'math' grades**
#
# 2.-**Explain from the perspective of Association, Correlation and Relationship if there is any dependency between the grades in 'math' and 'read'**
#
# 3.-**Explain the barplot that may come from the crosstab of the variables 'public' and 'gender'**
